# %%
# !ls /content
# Out:
#  drive	'input_data (1).npz'   sample_data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
 # Load the .npz file (adjust the file name based on what you find in /content)
data = np.load('/content/input_data.npz')

print("Available keys in the .npz file:", data.files)
# Out:
# Available keys in the .npz file: ['X_train', 'Y_train', 'X_validation', 'Y_validation']

# %%
# Load the .npz file
data = np.load('/content/input_data.npz')

# Access the images and labels
X_train = data['X_train']
Y_train = data['Y_train']
X_validation = data['X_validation']
Y_validation = data['Y_validation']

# Display the shapes of the arrays
print(f'X_train shape: {X_train.shape}')
print(f'Y_train shape: {Y_train.shape}')
print(f'X_validation shape: {X_validation.shape}')
print(f'Y_validation shape: {Y_validation.shape}')
# Out:
# X_train shape: (4113, 75, 75, 3)
# Y_train shape: (4113,)
# X_validation shape: (100, 75, 75, 3)
# Y_validation shape: (100,)

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define paths (update 'dataset_directory' with the actual path to your dataset)
data = np.load('/content/input_data.npz')

# Image Data Generator for data augmentation
datagen = ImageDataGenerator(
    rescale=1./255,  # Normalize pixel values (0-255) to [0, 1]
    rotation_range=20,  # Rotate images randomly by up to 20 degrees
    width_shift_range=0.2,  # Horizontally shift images by 20%
    height_shift_range=0.2,  # Vertically shift images by 20%
    zoom_range=0.2,  # Randomly zoom into images by 20%
    horizontal_flip=True,  # Randomly flip images horizontally
    validation_split=0.1  # Reserve 10% of the data for validation
)
